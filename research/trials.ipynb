# %%
# here do only practice purpos use
# here we use data collection logic.

# %%
import os

# %%
os.getcwd()
# Out:
# 'd:\\ITVedant\\Final_Project_AIML-DL\\Kidney_tumour_prediction_system\\research'

# %%
# Data ingestion >> data collection

# %%
# Steps :

# 1)    Config.yaml
# 2)    Params.yaml
# 3)    Entity
# 4)    Configuration manager
# 5)    Components
# 6)    Pipeline
# 7)     main.py

# %%
# Step 1) Update config.yaml file.

# %%
# Step 2) Updates params.yaml.

# %%
# Step 3) Entity .

# %%
os.chdir("../")  #its use for change directory resrch to kidney prediction

# %%
os.getcwd()  # now check here working directory chnaged
# Out:
# 'd:\\ITVedant\\Final_Project_AIML-DL\\Kidney_tumour_prediction_system'

# %%
# put entity code  now: ( menase mention data types of config.yml 's entity's)

from dataclasses import dataclass
from pathlib import Path




@dataclass(frozen=True)
class DataIngestionConfig:
   root_dir: Path
   source_URL: str
   local_data_file: Path
   unzip_dir: Path

# %%
# Step 4) Configuration manager : (here actual values assigne)

# %%
from src.cnnClassifier import *
from src.cnnClassifier.utils.common import read_yaml,create_directories

class ConfigurationManager:
    def __init__(
        self,
        config_filepath = Path("config/config.yaml"),
        params_filepath = Path("params.yaml")):


        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)


        create_directories([self.config.artifacts_root])




   
    def get_data_ingestion_config(self) -> DataIngestionConfig:
        config = self.config.data_ingestion


        create_directories([config.root_dir])


        data_ingestion_config = DataIngestionConfig(
            root_dir=config.root_dir,
            source_URL=config.source_URL,
            local_data_file=config.local_data_file,
            unzip_dir=config.unzip_dir
        )


        return data_ingestion_config

# %%
#Step 5) Components: (here actual data download process code)

# %%
import os
import zipfile
import gdown
from src.cnnClassifier import logger
from src.cnnClassifier.utils.common import get_size


class DataIngestion:
    def __init__(self, config: DataIngestionConfig):
        self.config = config


   
    def download_file(self)-> str:
        '''
        Fetch data from the url
        '''


        try:
            dataset_url = self.config.source_URL
            zip_download_dir = self.config.local_data_file
            os.makedirs("artifacts/data_ingestion", exist_ok=True)
            logger.info(f"Downloading data from {dataset_url} into file {zip_download_dir}")


            file_id = dataset_url.split("/")[-2]
            prefix = 'https://drive.google.com/uc?/export=download&id='
            gdown.download(prefix+file_id,zip_download_dir)


            logger.info(f"Downloaded data from {dataset_url} into file {zip_download_dir}")


        except Exception as e:
            raise e
       
   


    def extract_zip_file(self):
        """
        zip_file_path: str
        Extracts the zip file into the data directory
        Function returns None
        """
        unzip_path = self.config.unzip_dir
        os.makedirs(unzip_path, exist_ok=True)
        with zipfile.ZipFile(self.config.local_data_file, 'r') as zip_ref:
            zip_ref.extractall(unzip_path)

# %%
#step 6) Pipeline :( here actual create object's of all and call function's and run to download and extract)

# %%
try:
    config = ConfigurationManager()
    data_ingestion_config = config.get_data_ingestion_config()
    data_ingestion = DataIngestion(config=data_ingestion_config)
    data_ingestion.download_file()
    data_ingestion.extract_zip_file()
except Exception as e:
    raise e
# Out:
# [2026-05-14 09:12:30,998: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2026-05-14 09:12:32,941: INFO: common: yaml file: params.yaml loaded successfully]
# [2026-05-14 09:12:32,957: INFO: common: created directory at: artifacts]
# [2026-05-14 09:12:32,963: INFO: common: created directory at: artifacts/data_ingestion]
# [2026-05-14 09:12:32,970: INFO: 1230875562: Downloading data from https://drive.google.com/file/d/1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3/view?usp=sharing into file artifacts/data_ingestion/data.zip]
# Downloading...
# From (original): https://drive.google.com/uc?id=1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3
# From (redirected): https://drive.google.com/uc?id=1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3&confirm=t&uuid=7539b062-53eb-4981-92aa-d40d7b547146
# To: d:\ITVedant\Final_Project_AIML-DL\Kidney_tumour_prediction_system\artifacts\data_ingestion\data.zip
# 100%|██████████| 57.7M/57.7M [00:19<00:00, 2.97MB/s]
# [2026-05-14 09:12:55,559: INFO: 1230875562: Downloaded data from https://drive.google.com/file/d/1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3/view?usp=sharing into file artifacts/data_ingestion/data.zip]
